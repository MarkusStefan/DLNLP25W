# %% [markdown]
# Task
# Your agent receives English sentences and must return German translations. Translation quality is measured using BLEU score (0-100, higher is better).
#
# Submission Format
# Your submission must include:
#
# File: agent.py
# Class: Agent
# Method: def predict(self, X_test: np.ndarray) -> np.ndarray
# You can include additional files, methods, and weight files (.pt, .pth, etc.).
#
# Let me search more specifically for the ml-arena translate repository:Based on the README content you provided, I can create examples of the data format. Let me add a section to clarify the input/output format:
#
# Data Format
# Input (X_test): NumPy array of English sentences (strings)
#
# X_test = np.array([
#     "Hello, how are you?",
#     "The weather is nice today.",
#     "I love machine learning."
# ], dtype=object)
# Output (predictions): NumPy array of German translations (strings)
#
# predictions = np.array([
#     "Hallo, wie geht es dir?",
#     "Das Wetter ist heute schön.",
#     "Ich liebe maschinelles Lernen."
# ], dtype=object)
# Competition Constraints
#
#
#
#
# What is a Submission?
# A submission consists of your agent's code and model files that will run in your selected runtime environment. The main requirements are:
#
# Required Files
#
# • agent.py with Agent class
#
# • Model weights (if using ML)
#
# • Additional helper modules
#
# Storage Limits
#
# • Total size:
#
# • Max files:
#
# Agent Structure
# Your agent.py must implement the following interface to interact with the environment:
#
# import numpy as np
# import random
#
# class Agent:
#     """Random baseline agent that generates random German words"""
#
#     def __init__(self):
#         # Common German words for random baseline
#         self.german_words = [
#             "Hallo", "Guten", "Morgen", "Tag", "Abend", "Nacht",
#             "danke", "bitte", "ja", "nein", "gut", "sehr",
#             "ist", "der", "die", "das", "und", "oder",
#             "ich", "du", "er", "sie", "wir", "ihr",
#             "haben", "sein", "werden", "können", "müssen",
#             "hier", "dort", "heute", "morgen", "gestern"
#         ]
#
#     def reset(self):
#         pass  # No state to reset
#
#     def predict(self, X_test: np.ndarray) -> np.ndarray:
#         """Generate random German 'translations'"""
#         translations = []
#
#         for sentence in X_test:
#             # Generate random translation with 3-7 words
#             num_words = random.randint(3, 7)
#             translation = " ".join(random.choices(self.german_words, k=num_words))
#             translations.append(translation)
#
#         return np.array(translations, dtype=object)

# %%
import sys
sys.path.append('../src')

from agent import Agent
